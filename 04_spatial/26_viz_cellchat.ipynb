# %%
suppressMessages(library(Seurat))
suppressMessages(library(ggplot2))
suppressMessages(library(patchwork))
suppressMessages(library(dplyr))
suppressMessages(library(CellChat))
suppressMessages(library(foreach))

# %%
CellChatDB <- CellChatDB.human
showDatabaseCategory(CellChatDB)
CellChatDB.use <- subsetDB(CellChatDB)
# Out:
# plot without title

# %%
df <- as.data.frame(unique(CellChatDB.use$interaction$pathway_name))

# %%
options(repr.plot.height = 10, repr.plot.width = 10)

# %%
sample_list <- c('HC01', 'HC02', 'HC03', 'HC05', 
                 'SSc4994', 'SSc5380', 
               'SSc-HL01', 'SSc-HL05', 'SSc-HL06', 'SSc-HL11',
               'SSc-HL13', 'SSc-HL25', 'SSc-HL33', 'SSc-HL35')

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/HC01.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/HC02.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/HC03.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/HC05.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc4994.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc5380.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL05.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL06.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL11.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL13.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL25.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL33.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”

# %%
cellchat <- readRDS("../../results/04_spatial/25_cellchat/SSc-HL35.rds")

p <- netVisual_circle(cellchat@net$count, 
                      vertex.weight = rowSums(cellchat@net$count), 
                      weight.scale = T, label.edge= T)
# Out:
# Plot with title “”
