# %%
suppressMessages(library(Seurat))
suppressMessages(library(ggplot2))
suppressMessages(library(patchwork))
suppressMessages(library(dplyr))
suppressMessages(library(viridis))
suppressMessages(library(cowplot))

# %%
plot_marker <- function(obj, marker, pt.size.factor = 1.2){
    p <- SpatialFeaturePlot(obj, features = marker,
                            max.cutoff = "q99", 
                            min.cutoff = "q1",
                            pt.size.factor = pt.size.factor, 
                            image.alpha = 0) +
        scale_fill_viridis(option = 'A') +
        xlab("") + ylab("") +
        theme_cowplot() +
        theme(axis.text = element_blank(),
              axis.line = element_blank(),
              axis.ticks = element_blank())
    
    
    return(p)


}

# %%
input_dir <- "../../results/04_spatial/01_read_data"

# %%
plot_list <- SpatialFeaturePlot(obj, features = c("POSTN", "APOD"),
                            max.cutoff = "q99", 
                            min.cutoff = "q1",
                            pt.size.factor = 1.5, 
                            image.alpha = 0) +
        xlab("") + ylab("") +
        theme_cowplot() +
        theme(axis.text = element_blank(),
              axis.line = element_blank(),
              axis.ticks = element_blank())

# %%
print(plot_list)
# Out:
# plot without title

# %%
options(repr.plot.height = 4, repr.plot.width = 20)

obj <- readRDS(glue::glue("{input_dir}/SSc4994.rds"))

p1 <- plot_marker(obj, marker = 'SCARA5', pt.size.factor = 2)
p2 <- plot_marker(obj, marker = 'POSTN', pt.size.factor = 1.5)
p3 <- plot_marker(obj, marker = 'APOD', pt.size.factor = 1.5)
p4 <- plot_marker(obj, marker = 'FOS', pt.size.factor = 1.5)
p5 <- plot_marker(obj, marker = 'COCH', pt.size.factor = 1.5)
p5 <- plot_marker(obj, marker = 'APOE', pt.size.factor = 1.5)

p <- p1 + p2 + p3 + p4 + p5 + plot_layout(ncol = 5)

print(p)
# Out:
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# plot without title
