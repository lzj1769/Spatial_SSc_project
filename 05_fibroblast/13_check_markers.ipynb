# %%
import os
import warnings
warnings.filterwarnings('ignore')

import scanpy as sc
import anndata as ad
import pandas as pd
import seaborn as sns
import decoupler as dc

# %%
adata = sc.read_h5ad('../../results/05_fibroblast/01_clustering/fibroblast.h5ad')

# %%
markers = {"Cluster_0": ["CCL19", "C7", "APOE"],
           "Cluster_1": ["PCOLCE2"],
           "Cluster_2": ["POSTN", "ASPN"],
           "Cluster_3": ["SFRP2", "WIF1"],
           "Cluster_4": ["SFRP2", "PRSS23"],
           "Cluster_5": ["CRABP1", "COCH"],
           "Cluster_6": ["MYOC"],
           "Cluster_7": ["ANGPTL7"],
           "Cluster_8": ["COL11A1"],
           "Cluster_9": ["TUBA1B"]}

# %%
sc.pl.matrixplot(adata, markers, 'sub_clusters', dendrogram=True, standard_scale='var',
                 colorbar_title='Z-scaled scores')
# Out:
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Fib1, Fib2, Fib3, etc.
# var_group_labels: Cluster_0, Cluster_1, Cluster_2, etc.

# %%
markers = {"Fibro_ACTA2": ["ACTA2"],
           "Fibro_COCH": ["COCH"],
           "Fibro_COMP": ["COMP"],
           "Fibro_LGR5": ["LGR5"],
           "Fibro_POSTN": ["POSTN"],
           # "Fibro_POSTN_PTGDS": ["POSTN", "PTGDS"],
           "Fibro_MYOC": ["MYOC"],
           "Fibro_PTGDS": ["PTGDS"],
           "Fibro_IGFBP2": ["IGFBP2"],}

# %%
sc.pl.matrixplot(adata, markers, 'sub_clusters', dendrogram=True, standard_scale='var',
                 colorbar_title='Z-scaled scores')
# Out:
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Fib1, Fib2, Fib3, etc.
# var_group_labels: Fibro_ACTA2, Fibro_COCH, Fibro_COMP, etc.
